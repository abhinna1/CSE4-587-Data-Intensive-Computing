# %%
import pandas as pd

df = pd.read_csv("dataset/notable_ai_models.csv")

# %%
df.drop(columns=["Authors"], inplace=True)  # Drop Authors column.

# %%
df.drop(columns=["Citations"], inplace=True)  # Drop Citations column.
# Out:
#                                   Model        Domain  \
# 0                        Doubao-1.5-pro      Language
# 1                           DeepSeek-R1      Language
# 2                           DeepSeek-V3      Language
# 3                                 Veo 2  Video,Vision
# 4                             Llama 3.3      Language
# ..                                  ...           ...
# 886  Sequence-based pattern recognition        Vision
# 887              Self Organizing System         Other
# 888                   Genetic algorithm   Mathematics
# 889                               SNARC      Robotics
# 890                             Theseus      Robotics
#
#                                     Organization Organization categorization  \
# 0                                      ByteDance                    Industry
# 1                                       DeepSeek                    Industry
# 2                                       DeepSeek                    Industry
# ...

# %%
df.drop(columns=["Notability criteria"], inplace=True)  # Drop Notability criteria column.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.drop(columns=["Notibility"], inplace=True)
#
# File ~/Downloads/yes/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
df
